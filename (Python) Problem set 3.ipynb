# %% [markdown]
# # Question 1

# %%
#when first time i run, it was succesfully run but after completion of all question I restart all kernel then I again run, i got this error message in all question


#step 1
import pandas as pd
#step 2
#step 3
users = pd.read_csv('data123.txt')

# %%
users
# Out:
#     user_id|age|gender|occupation|zip_code
# 0                  1|24|M|technician|85711
# 1                       2|53|F|other|94043
# 2                      3|23|M|writer|32067
# 3                  4|24|M|technician|43537
# 4                       5|33|F|other|15213
# ..                                     ...
# 938                 939|26|F|student|33319
# 939           940|32|M|administrator|02215
# 940                 941|20|M|student|97229
# 941               942|48|F|librarian|78209
# 942                 943|22|M|student|77841
#
# [943 rows x 1 columns]

# %%
#step 4
users.groupby('occupation')['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-3e87cd3f378b> in <module>
#       1 #step 4
# ----> 2 users.groupby('occupation')['age'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ...

# %%
#step 5
users[users.gender == 'M'].groupby('occupation')['gender'].count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-498bbd5d84a1> in <module>
#       1 #step 5
# ----> 2 users[users.gender == 'M'].groupby('occupation')['gender'].count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'gender'

# %%
#step 6
users.groupby('occupation')['age'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-927415393c1b> in <module>
#       1 #step 6
# ----> 2 users.groupby('occupation')['age'].max()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ...

# %%
#step 6
users.groupby('occupation')['age'].min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-462ddc902d15> in <module>
#       1 #step 6
# ----> 2 users.groupby('occupation')['age'].min()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ...

# %%
#step 7
users.groupby(['occupation', 'gender'])['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-5cd29e06c047> in <module>
#       1 #step 7
# ----> 2 users.groupby(['occupation', 'gender'])['age'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
# ...

# %%
#step 8
users[users.gender == 'M'].groupby('occupation').count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-95b74a9993f2> in <module>
#       1 #step 8
# ----> 2 users[users.gender == 'M'].groupby('occupation').count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'gender'

# %%
#step 8
users[users.gender == 'F'].groupby('occupation').count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-556ac6acc99a> in <module>
#       1 #step 8
# ----> 2 users[users.gender == 'F'].groupby('occupation').count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'gender'

# %% [markdown]
# # Question 2

# %%
#step 1

import pandas as pd
import numpy as np

#step 2
#step 3
euro12 = pd.read_csv('data2.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 4
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#step 5
euro12.shape[0]
# Out:
# 16

# %%
#step 6
euro12.shape[1]
# Out:
# 35

# %%
#step 7
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#step 8
discipline.sort_values(['Yellow Cards', 'Red Cards'])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#step 9
euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#step 10
euro12[euro12.Goals>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#step 11
euro12.Team.str.startswith('G')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Team, dtype: bool

# %%
#step 12
euro12.iloc[:, :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 13
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 14
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Shooting Accuracy']]
# Out:
#    Shooting Accuracy
# 3              50.0%
# 7              43.0%
# 12             22.5%

# %% [markdown]
# # Question 3

# %%
#step 1
import pandas as pd
import numpy as np

# %%
#step 2
a1 = pd.Series(np.random.int(1,4, size=(100)))
a2 = pd.Series(np.random.int(1,3, size=(100)))
a3 = pd.Series(np.random.int(10000,30000, size=(100)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-9fde6dcee206> in <module>
#       1 #step 2
# ----> 2 a1 = pd.Series(np.random.int(1,4, size=(100)))
#       3 a2 = pd.Series(np.random.int(1,3, size=(100)))
#       4 a3 = pd.Series(np.random.int(10000,30000, size=(100)))
#
# AttributeError: module 'numpy.random' has no attribute 'int'

# %%
#step 3
dataframe = pd.DataFrame({'a1':a1,'a2':a2,'a3':a3})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-2ab86c45edb9> in <module>
#       1 #step 3
# ----> 2 dataframe = pd.DataFrame({'a1':a1,'a2':a2,'a3':a3})
#
# NameError: name 'a1' is not defined

# %%
#step 4
dataframe.rename(columns = {'a1':'bedrs', 'a2':'bathrs', 'a3':'price_sqr_meter'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-06861a173bb9> in <module>
#       1 #step 4
# ----> 2 dataframe.rename(columns = {'a1':'bedrs', 'a2':'bathrs', 'a3':'price_sqr_meter'})
#
# NameError: name 'dataframe' is not defined

# %%
#step 5
dataframe2 = pd.DataFrame({'bigcolumn': [a1, a2, a3]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-083d43dbf747> in <module>
#       1 #step 5
# ----> 2 dataframe2 = pd.DataFrame({'bigcolumn': [a1, a2, a3]})
#
# NameError: name 'a1' is not defined

# %% [raw]
# #step 6
#
# Ops it seems it is going only until index 99. Is it true?
#
# yes
# it is true

# %%
#step 7
dataframe2.reindex = pd.Index(start=0, stop=300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-14fcfa895fce> in <module>
#       1 #step 7
# ----> 2 dataframe2.reindex = pd.Index(start=0, stop=300)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     370
#     371         elif data is None or is_scalar(data):
# --> 372             raise cls._scalar_data_error(data)
#     373         elif hasattr(data, "__array__"):
#     374             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, None was passed

# %% [markdown]
# # Question 4

# %%
#step 1

import numpy as np
import pandas as pd
import datetime

# %%
#step 2

data = pd.read_csv('wind.txt')
data
# Out:
#      Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 0     61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 1...
# 1     61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 1...
# 2     61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 1...
# 3     61  1  4 10.58  6.63 11.75  4.58  4.54  2.88  ...
# 4     61  1  5 13.33 13.25 11.42  6.17 10.71  8.21 1...
# ...                                                 ...
# 6569  78 12 27 17.58 16.96 17.62  8.08 13.21 11.67 1...
# 6570  78 12 28 13.21  5.46 13.46  5.00  8.12  9.42 1...
# 6571  78 12 29 14.00 10.29 14.42  8.71  9.71 10.54 1...
# 6572  78 12 30 18.50 14.04 21.29  9.13 12.75  9.71 1...
# 6573  78 12 31 20.33 17.41 27.29  9.59 12.08 10.13 1...
#
# [6574 rows x 1 columns]

# %%
#step 3
data=pd.read_csv('wind.txt',sep="\s+")
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
#step4

# %%
#step 5

# %%
#step 6
data.isnull().sum()
# Out:
# Yr     0
# Mo     0
# Dy     0
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
#step 7

data.notnull().sum()
# Out:
# Yr     6574
# Mo     6574
# Dy     6574
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
#step 8
data.mean().mean()
# Out:
# 14.299199599246556

# %%
#step 9
loc_stats = pd.DataFrame()
loc_stats['min'] = data.min()
loc_stats['max'] = data.max()
loc_stats['mean'] = data.mean()
loc_stats['std'] = data.std()
loc_stats
# Out:
#        min    max       mean       std
# Yr   61.00  78.00  69.500304  5.188131
# Mo    1.00  12.00   6.523274  3.448871
# Dy    1.00  31.00  15.728628  8.800335
# RPT   0.67  35.80  12.362987  5.618413
# VAL   0.21  33.37  10.644314  5.267356
# ROS   1.50  33.84  11.660526  5.008450
# KIL   0.00  28.46   6.306468  3.605811
# SHA   0.13  37.54  10.455834  4.936125
# BIR   0.00  26.16   7.092254  3.968683
# DUB   0.00  30.37   9.797343  4.977555
# CLA   0.00  31.08   8.495053  4.499449
# MUL   0.00  25.88   8.493590  4.166872
# CLO   0.04  28.21   8.707332  4.503954
# BEL   0.13  42.38  13.121007  5.835037
# MAL   0.67  42.54  15.599079  6.699794

# %%
#step10
day_stats = pd.DataFrame()
day_stats['min'] = data.min()
day_stats['max'] = data.max()
day_stats['mean'] = data.mean()
day_stats['std'] = data.std()

day_stats.head()
# Out:
#        min    max       mean       std
# Yr   61.00  78.00  69.500304  5.188131
# Mo    1.00  12.00   6.523274  3.448871
# Dy    1.00  31.00  15.728628  8.800335
# RPT   0.67  35.80  12.362987  5.618413
# VAL   0.21  33.37  10.644314  5.267356

# %%
#step 11

# %%
#step 12
data.query()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-3d50eca73775> in <module>
#       1 #step 12
# ----> 2 data.query()
#
# TypeError: query() missing 1 required positional argument: 'expr'

# %%
#step 13

data.query()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-72f1ef1f5efe> in <module>
#       1 #step 13
#       2
# ----> 3 data.query()
#
# TypeError: query() missing 1 required positional argument: 'expr'

# %%
#step 14

# %%
#step 15

# %% [markdown]
# # Question 5

# %%
#step 1
import pandas as pd
import numpy as np

# %%
#step 2 & 3
chipo = pd.read_csv('chipotle.tsv', sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#step 4
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step 5

chipo.shape[0]
# Out:
# 4622

# %%
#step 6
chipo.shape[1]
# Out:
# 5

# %%
#step 7
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step 8
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#step 9

chipo[chipo.quantity == chipo.quantity.max()].item_name
# Out:
# 3598    Chips and Fresh Tomato Salsa
# Name: item_name, dtype: object

# %%
#step 10

chipo[chipo.quantity == chipo.quantity.max()].quantity
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %%
#step 11
chipo.groupby('choice_description').agg({'quantity':'sum'}).sort_values(by='quantity')
# Out:
#                                                     quantity
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# ...                                                      ...
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        49
# [Sprite]                                                  89
# [Coke]                                                   143
# [Diet Coke]                                              159
#
# [1043 rows x 1 columns]

# %%
#step 12
chipo.quantity.sum()
# Out:
# 4972

# %%
#step 13
chipo['item_price'] = chipo['item_price'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-066a863c7f43> in <module>
#       1 #step 13
# ----> 2 chipo['item_price'] = chipo['item_price'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
chipo['item_price'].dtype
# Out:
# dtype('O')

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float())

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %%
#step 14

chipo['item_price'].sum()
# Out:
# 0.0

# %%
#step 15
len(chipo.groupby('order_id').agg({'order_id':'count'}))
# Out:
# 1834

# %%
#step 16

chipo.groupby('order_id').agg({'item_price':'mean'}).mean()
# Out:
# item_price    0.0
# dtype: float64

# %%
#step 17
len(chipo.groupby('item_name').agg({'item_name':'count'}))
# Out:
# 50

# %% [markdown]
# # Question 6

# %%
#libraries 
import pandas as pd
import matplotlib.pyplot as plot

#import data
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')

#plot the graph
plot.figure()

#pass the parameters
data .plot('Year',y=['Marriages','Divorces'])

#display
plot.show()

# %% [markdown]
# # Question 7

# %%
#libraries
import numpy as np
import matplotlib.pyplot as plot

#import data
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
plot.figure()

#three different data with bar
X = np.arange(len(marriage))

#pass the  parameters

plot.bar(X, marriage)
plot.bar(X, divorce)

#filtering and condition
plot.xticks([i for i in range(3)], ['1900', '1950', '2000'])

#title
plot.title("Bar Chart")

#label to axies
plot.xlabel('Divorce in between 1900, 1950 & 2000')
plot.ylabel('Total')

#display
plot.show()

# %% [markdown]
# # Question 8

# %%
#libraries
import pandas as pd
import matplotlib.pyplot as plot

#import data set
data= pd.read_csv('actor_kill_counts.csv')

#bar chart and pass parameters
data.plot.barh(x='Actor', y='Count')

#lebel
plot.ylabel('actor')
plot.xlabel('kill')

#display the chart
plot.show()

# %% [markdown]
# # Question 9

# %%
#libraries
import pandas as pd
import matplotlib.pyplot as plot

#import data set
data = pd.read_csv("roman-emperor-reigns.csv")

#passing parameters
data = data[data['Cause_of_Death'] == "Assassinated" ]

#size of chart
plot.figure(figsize=(7,7))
patches, texts = plot.pie(data.Length_of_Reign)
plot.legend(data.Emperor)

#display
plot.show()

# %% [markdown]
# # Question 10

# %%
#libraries
import pandas as pd
import matplotlib.pyplot as plot

#import dataset
data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')

a = data.groupby('Year')
for name, group in a:
    #here i changed some modification in variable name in dataset
    #Total Arcade Revenue (billions) = Total
    #Computer Science Doctorates Awarded (US) = Computer
    plot.plot(group.Total, group.Computer, marker='o', linestyle='', markersize=12, label=name)

plot.legend()
plot.xlabel("Total Arcade Revenue")
plot.ylabel("Computer Science Doctorates Awarded")

#display
plot.show()
