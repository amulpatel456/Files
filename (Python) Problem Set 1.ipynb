# %% [markdown]
# # Question 1 C#
#
# What data type is each of the following?

# %% [raw]
# 5  Integer
# 5.0  Float
# 5 > 1  boolean
# '5' Character
# 5 * 2 Integer
# '5' * 2 String
# '5' + '2' String
# 5 / 2 Float
# 5 % 2 Integer
# {5, 2, 1} Array
# 5 == 3 Boolean
# Pi (the number) 3.14 = Float //  3.142857..... = Double

# %% [markdown]
# # Question 2 C#   A
#
# How many letters are there in 'Supercalifragilisticexpialidocious'?

# %% [raw]
# using System;
# using System.Collections.Generic;
# using System.Linq;
# using System.Text;
#
# //defining namespace
#
# namespace ConsoleApp1
# {
#
# //define class as Question 2A
#
#     class Q2A
#     {
#         static void Main(string[] args)
#         {
#
#         //string variable
#
#             string var = "Supercalifragilisticexpialidocious";
#
#           //define string counter
#
#             int number = 0;
#             for (int i = 0; i < var.Length; i++)
#             {
#                 number++;
#             }
#
#             Console.WriteLine(number);
#             Console.Read();
#         }
#     }
# }

# %% [markdown]
# # Question 2 C#   B
#
# Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

# %% [raw]
# using System;
# using System.Collections.Generic;
# using System.Linq;
# using System.Text;
#
# //defining namespace
#
# namespace ConsoleApp2
# {
#
# //defining class as question 2 B
#
#     class Q2B
#     {
#         static void Main(string[] args)
#         {
#         // parents string
#
#             string s1 = "Supercalifragilisticexpialidocious";
#
#          // child string
#
#             string s2 = "ice";
#
#           // String containing
#
#             Console.WriteLine(s1.Contains(s2));
#             Console.ReadLine();
#
#         }
#     }
# }

# %% [markdown]
# # Question 2 C#   C
#
# Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or Bababadalgharaghtakamminarronnkonn?

# %% [raw]
# using System;
# using System.Collections.Generic;
# using System.Linq;
# using System.Text;
#
# //defining namespace
#
# namespace ConsoleApp3
# {
#
# //defining class as question 2 c
#
#     class Q2C
#     {
#         static void Main(string[] arg)
#         {
#
#         // mentioned 3 strings for finding which is longest
#
#             String letter = "Supercalifragilisticexpialidocious, Honorificabilitudinitatibus,Bababadalgharaghtakamminarronnkonn";
#             String[] words = letter.Split(new[] {" "}, StringSplitOptions.None);
#
#             String word = "";
#                 int ctr = 0;
#
#             foreach (String s1 in words)
#             {
#                 if(s1.Length > ctr)
#                 {
#                     word = s1;
#                     ctr = s1.Length;
#                 }
#
#             }
#
#             Console.WriteLine(word);
#             Console.ReadKey();
#
#         }
#     }
# }

# %% [markdown]
# # Question 2 C#   D
#
# Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
# 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

# %% [raw]
# using System;
# using System.Collections.Generic;
# using System.Linq;
# using System.Text;
#
# //define namespace
#
# namespace ConsoleApp4
# {
#
# //define class
#
#     class Q2D
#     {
#         static void Main(string[] args)
#         {
#
#         //mentioned strings which are going to be in dictionary form
#
#             string[] Composer = { "Berlioz", "Borodin", "Brian", "Bartok",
# "Bellini", "Buxtehude", "Bernstein" };
#
# //sortig array for dictonary order
#
#  Array.Sort(Composer, (a , b) => String.Compare(a , b));
#
#             Console.WriteLine($"First Composer :- {Composer[0]}");
#
#             Console.WriteLine($"Last Composer :- { Composer[Composer.Length - 1]}");
#         }
#     }
# }

# %% [markdown]
# # Question 3 C#
#
# Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
# sides of a triangle and returns the area of the triangle. By Heron's formula, the area
# of a triangle with side lengths a, b, and c is
# s(s - a)(s -b)(s -c)
# , where
# s = (a+b+c)/2.

# %% [raw]
# using System;
# using System.Collections.Generic;
# using System.Linq;
# using System.Text;
#
#
# namespace ConsoleApp5
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#             double a , b , c;
#             double s , area ;
#
#             //parameters from user
#
#             Console.WriteLine("A side of tringle area:- ");
#             a = double.Parse(Console.ReadLine());
#             Console.WriteLine("B side of tringle area:- ");
#             b = double.Parse(Console.ReadLine());
#             Console.WriteLine("C side of tringle area:- ");
#             c = double.Parse(Console.ReadLine());
#
#             //formula
#
#             s = (a + b + c) / 2;
#             area = Math.Sqrt(s*(s - a)*(s - b)*(s - c));
#             Console.WriteLine("The Area of Tringle is :- " + area);
#             Console.ReadLine();
#
#         }
#     }
# }

# %% [markdown]
# # Question 4 C#
#
# Write a program in C# Sharp to separate odd and even integers in separate arrays.

# %% [raw]
# using System;
# using System.Collections.Generic;
# using System.Linq;
# using System.Text;
#
# //public class
# public class Amul
# {
#     public static void Main()
#     {
#         int[] arr1 = new int[10];
#         int[] arr2 = new int[10];
#         int[] arr3 = new int[10];
#         int a, b = 0, c = 0, d;
#
# //here user have to input number of elements
#         Console.Write("Input the number of elements to be stored in the array :- ");
#         d = Convert.ToInt32(Console.ReadLine());
# //here user have to enter element of array
#
#         Console.Write(" Input {0} elements in the array :- \n", d);
#         for (a = 0; a < d; a++)
#         {
#             Console.Write(" element - {0} :- ", a);
#             arr1[a] = Convert.ToInt32(Console.ReadLine());
#         }
# //for loop for finding odd or even
#
#         for (a = 0; a < d; a++)
#         {
#             if (arr1[a] % 2 == 0)
#             {
#                 arr2[b] = arr1[a];
#                 b++;
#             }
#             else
#             {
#                 arr3[c] = arr1[a];
#                 c++;
#             }
#         }
#
# //for loop for even number
#         Console.Write("The Even elements are : \n");
#         for (a = 0; a < c; a++)
#         {
#             Console.Write("{0} ", arr2[a]);
#         }
#
# //for loop for odd number
#
#         Console.Write(" The Odd elements are : \n");
#         for (a = 0; a < c; a++)
#         {
#             Console.Write("{0} ", arr3[a]);
#         }
#         Console.Write("\n");
#     }
# }

# %% [markdown]
# # Question 5 C#
#
# a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
# depending on whether the point (x,y) lies in the rectangle with lower left
# corner (x1,y1) and upper right corner (x2,y2).
# b. Use function inside() from part a. to write an expression that tests whether
# the point (1,1) lies in both of the following rectangles: one with lower left
# corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
# left corner (0.5, 0.2) and upper right corner (1.1, 2)

# %% [raw]
# using System;
# using System.Collections.Generic;
# using System.Linq;
# using System.Text;
#
# //namespace
# namespace ConsoleApp7
# {
# //class as Amul name
#     class Amul
#     {
#         static bool inside(double x, double y, double x1, double y1, double x2,
#         double y2 )
#         {
# //if statement
#             if (x > x1 && x < x2 &&
#             y > y1 && y < y2)
#                 return true;
#             return false;
#         }
#         static void Main(string[] args)
#         {
# //user have to write value here
#             Console.Write("X :- ");
#             double x = Convert.ToDouble(Console.ReadLine());
#             Console.Write("X1 :-");
#             double x1 = Convert.ToDouble(Console.ReadLine());
#             Console.Write("X2 :- ");
#             double x2 = Convert.ToDouble(Console.ReadLine());
#             Console.Write("Y :- ");
#             double y = Convert.ToDouble(Console.ReadLine());
#             Console.Write("Y1 :- ");
#             double y1 = Convert.ToDouble(Console.ReadLine());
#             Console.Write("Value of Y2 :- ");
#             double y2 = Convert.ToDouble(Console.ReadLine());
# //if else statement for weather it is rectangle with lower and upper corner
#             if (inside(x, y, x1, y1, x2, y2))
#                 Console.Write("true");
#             else
#                 Console.Write("false");
#         }
#     }
# }

# %% [markdown]
# # Question 6 Python

# %%
#define pig function
def pig(word):
#if and else for vovalce
 if letter[0] in "AEIOUaeiou":
    return letter + 'way'
    
 else:
    return letter[1:] + letter[0] + 'ay'
#user inter pig
letter = input("pig:-")
print(pig(letter).lower())
# Out:
# pig:-apple
# appleway

# %% [markdown]
# # Question 7 Python

# %%
#define bldcount function
def bldcount(bloodtype1):
#load a file here
    infile=open("bloodtype1.txt", 'r')
    content= infile.read('r')
    infile.close() 
    content = content.split() 
    return len(content)
    
#for loop for patients blood types   
for i in bloodtype1:
    
     if content.count(i)==0:
            
            print('There are no patients of blood type',i+'.')
     elif content.count(i)==1:
            print('There is 1 patient of blood type',i+'.')
     else:
            print('There are',content.count(i),'patients of blood type', i+'.')

# %% [markdown]
# # Question 8 Python

# %%
#define curconv function
def curconv(name,money):
#file open
    with open("currencies.txt")as x:
#for loop for money conversion 
        for num,currency in enumerate(x,1):
            if name in currency:
                data=list(line.split())
                print(double(money) * double(data[1]))
#enter name of currency
name = input("Unit Of Currency:-")
#amount which are going to convert
money = input("Enter The Amount:-")
curconv(name,money)

# %% [markdown]
# # Question 9 Python

# %% [markdown]
# Trying to add incompatible variables, as in adding 6 + ‘a’
#
# => TypeError
#
# Referring to the 12th item of a list that has only 10 items
#
# => IndexError
#
# Using a value that is out of range for a function’s input, such as calling math.sqrt(-1.0)
#
# => ValueError
#
# Using an undeclared variable, such as print(x) when x has not been defined
#
# => NameError
#
# Trying to open a file that does not exist, such as mistyping the file name or looking in the wrong directory
#
# => FileNotFoundError

# %% [markdown]
# # Question 10 Python

# %%
#get a string fro user
string_from_user = input('Enter your String:-')
#frequences fuction
def frequencies(string_from_user):
  #string split  
    s1= user_str.split()
    x = {}
#forloop for number od character     
    for i in s1:
       x[ord(i) - ord('a')] +=1
    print(x)
    
frequencies(string_from_user)
